# %% [markdown]
# <a href="https://colab.research.google.com/github/CREATION1310/bert/blob/master/Bert_Chat_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers ipywidgets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 60.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.0 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import ipywidgets as widgets
from transformers import BertModel, BertTokenizer
import torch

# Load BERT model
model = BertModel.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# Create a text input widget
text_input = widgets.Textarea(
    value='',
    placeholder='Type something',
    description='Text:',
    rows=10,
    layout=widgets.Layout(width="auto")
)

# %%
# Create a button
button = widgets.Button(description="Submit")

# Create an output widget
output = widgets.Output()

# %%
# Define the button click event
def on_button_clicked(b):
    with output:
        output.clear_output()
        text = text_input.value
        inputs = tokenizer(text, return_tensors='pt')
        outputs = model(**inputs)
        # Process the outputs to get the information you need
        # ...
        print(outputs)

button.on_click(on_button_clicked)

# %%
# Display the widgets
display(text_input, button, output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe90621aefbe> in <cell line: 2>()
#       1 # Display the widgets
# ----> 2 display(text_input, button, output)
#
# NameError: name 'text_input' is not defined
