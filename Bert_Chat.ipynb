# %% [markdown]
# <a href="https://colab.research.google.com/github/CREATION1310/bert/blob/master/Bert_Chat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install transformers ipywidgets

# Import necessary libraries
import ipywidgets as widgets
from transformers import BertModel, BertTokenizer
import torch

# Load BERT model
model = BertModel.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Create a text input widget
text_input = widgets.Textarea(
    value='',
    placeholder='Type something',
    description='Text:',
    rows=10,
    layout=widgets.Layout(width="auto")
)

# Create a button
button = widgets.Button(description="Submit")

# Create an output widget
output = widgets.Output()

# Define the button click event
def on_button_clicked(b):
    with output:
        output.clear_output()
        text = text_input.value
        inputs = tokenizer(text, return_tensors='pt')
        outputs = model(**inputs)
        # Process the outputs to get the information you need
        # ...
        print(outputs)

button.on_click(on_button_clicked)

# Display the widgets
display(text_input, button, output)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.1 MB/s eta 0:00:00
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# ...
